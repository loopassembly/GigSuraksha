# %% [markdown]
# # GigSuraksha ML EDA
#
# This notebook is a lightweight starting point for exploring the processed weekly risk dataset and validation outputs.

# %%
import csv
from pathlib import Path

ROOT = Path('/Users/loopassembly/Desktop/GigSuraksha/Ml')
dataset_path = ROOT / 'data' / 'processed' / 'weekly_risk_training_dataset.csv'
predictions_path = ROOT / 'reports' / 'validation_predictions.csv'

with dataset_path.open() as f:
    dataset_rows = list(csv.DictReader(f))

with predictions_path.open() as f:
    prediction_rows = list(csv.DictReader(f))

len(dataset_rows), len(prediction_rows)

# %%
dataset_rows[:3]
